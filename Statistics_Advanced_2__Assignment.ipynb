# %% [markdown]
# # Statistics Advanced - 2| Assignment

# %% [markdown]
# **Question 1: What is hypothesis testing in statistics?**

# %% [markdown]
# **Answer:** **Hypothesis testing** in statistics is a method used to make decisions or inferences about a population based on sample data. It involves testing an assumption (called a hypothesis) about a population parameter to determine whether there is enough evidence in the sample data to support or reject that assumption.
#
# **The process typically starts by defining two competing hypotheses:**
#
# >.The null hypothesis (H₀), which states there is no effect or difference (e.g., no change, no difference between groups).
#
# >.The alternative hypothesis (H₁ or Ha), which is the opposite and suggests there is an effect or difference.

# %% [markdown]
# **Question 2: What is the null hypothesis, and how does it differ from the alternative hypothesis?**

# %% [markdown]
# **Answer:** **The null hypothesis (denoted as H₀)** in statistics is a default or baseline assumption that there is no effect, no difference, or no relationship between variables in the population being studied. It essentially claims that any observed differences or effects in sample data are due to chance or random variation rather than a real underlying cause.
#
# In contrast, the alternative hypothesis (denoted as H₁ or Ha) is the statement that there is an effect, difference, or relationship. It is the hypothesis that researchers usually want to support by showing that the null hypothesis is unlikely given the sample data.

# %% [markdown]
# **Question 3: Explain the significance level in hypothesis testing and its role in deciding the outcome of a test.**

# %% [markdown]
# **Answer:** The significance level in hypothesis testing, denoted by the α (alpha), is a threshold set that  before we  conducting the test that defines the maximum probability of making a Type I error—that is, rejecting the null hypothesis when it is actually true.
#
# **Role and explanation:**
#
# >.It represents the cutoff point for deciding whether the observed data provide enough evidence to reject the null hypothesis.
#
# >.Commonly used significance levels are 0.05 (5%), 0.01 (1%), or 0.10 (10%), with 0.05 being the most typical.
#
# >.If the p-value (the probability of obtaining results as extreme as those observed assuming the null hypothesis is true) is less than or equal to α, the results are considered statistically significant, and the null hypothesis is rejected.
#
# >.If the p-value is greater than α, there is not enough evidence to reject the null hypothesis.

# %% [markdown]
# **Question 4: What are Type I and Type II errors? Give examples of each.**

# %% [markdown]
# **Answer:**  **Type I and Type II Errors in Hypothesis Testing-**
#
# **Type I Error (False Positive):**This error occurs when the null hypothesis is true, but it is incorrectly rejected. In other words, we conclude that there is an effect or difference when, in reality, there isn’t one.
#
# **Example:** A medical test indicates that a patient has a disease (rejecting the null hypothesis of "no disease") when the patient actually does not have the disease.
#
# **Type II Error (False Negative):** This error happens when the null hypothesis is false, but it fails to be rejected. In this case, we incorrectly conclude there is no effect or difference when one actually exists.
#
# **Example:** A medical test fails to detect a disease in a patient who actually has it (failing to reject the null hypothesis of "no disease" when it is false).

# %% [markdown]
# **Question 5: What is the difference between a Z-test and a T-test? Explain when to use each.**

# %% [markdown]
# **Answer:  Z-test** is a statistical test used to determine whether there is a significant difference between sample and population means or between the means of two samples.
#
# >It is typically used when the sample size is large (generally n > 30) and the population standard deviation is known. The Z-test is based on the standard normal distribution (Z-distribution).
#
# >The Z-test compares the means of two populations with a large sample size (typically ≥30) and known population standard deviation. It assesses whether the difference between the means is statistically significant.
#
# **T-test** is a statistical test used to determine whether there is a significant difference between the means of two groups.
#
# >It is particularly useful when the sample size is small (typically n < 30) and the population standard deviation is unknown. The T-test relies on the t-distribution, which is similar to the normal distribution but has heavier tails.
#
# **When to use each:**
#
# >Use a Z-test when the sample size is large (typically 30 or more) and the population standard deviation is known.
#
# >Use a T-test when the sample size is small (less than 30) and/or the population standard deviation is unknown.

# %% [markdown]
# **Question 6: Write a Python program to generate a binomial distribution with n=10 and p=0.5, then plot its histogram.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set parameters for the binomial distribution
n = 10
p = 0.5
size = 10000  # Number of samples

# Generate binomial distribution samples
data = np.random.binomial(n, p, size)

# Plot the histogram
plt.hist(data, bins=range(0, n+2), edgecolor='black', align='left')
plt.title('Binomial Distribution (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-1493129823.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# **Question 7: Implement hypothesis testing using Z-statistics for a sample dataset in Python. Show the Python code and interpret the results.**
#
# **sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
#                         50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5, 50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9, 50.3, 50.4, 50.0, 49.7, 50.5, 49.9]**

# %%
import numpy as np
from scipy.stats import norm

sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6, 50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7,
               50.2, 49.5, 50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9, 50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

n = len(sample_data)
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=0)  # Use population std

mu0 = 50  # Hypothesized mean

# Calculate the Z-statistic
z_stat = (sample_mean - mu0) / (sample_std / np.sqrt(n))

# Calculate the two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Sample Mean: {sample_mean}")
print(f"Sample Std Dev: {sample_std}")
print(f"Sample Size: {n}")
print(f"Z Statistic: {z_stat}")
print(f"P-value: {p_value}")
# Out:
# Sample Mean: 50.08888888888889
# Sample Std Dev: 0.5290335936496627
# Sample Size: 36
# Z Statistic: 1.0081275362005009
# P-value: 0.3133932398638155

# %% [markdown]
# **Question 8: Write a Python script to simulate data from a normal distribution and calculate the 95% confidence interval for its mean. Plot the data using Matplotlib.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Simulate data from a normal distribution
np.random.seed(42)
mu = 10
sigma = 2
n = 100

data = np.random.normal(mu, sigma, n)

# Calculate sample mean and standard deviation
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)

# Standard error
se = sample_std / np.sqrt(n)

# Z-value for 95% confidence
z = norm.ppf(0.975)

# 95% Confidence Interval
ci_lower = sample_mean - z * se
ci_upper = sample_mean + z * se
conf_int = (ci_lower, ci_upper)

# Plot histogram
plt.figure(figsize=(8,6))
plt.hist(data, bins=15, edgecolor='black', alpha=0.7)
plt.title('Normal Distribution Simulation')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-364953392.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# **Question 9: Write a Python function to calculate the Z-scores from a dataset and visualize the standardized data using a histogram. Explain what the Z-scores represent in terms of standard deviations from the mean.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    mean = np.mean(data)
    std = np.std(data, ddof=0)
    z_scores = (data - mean) / std
    return z_scores

# Simulate sample data
data = np.random.normal(10, 2, 100)

# Calculate Z-scores
z_scores = calculate_z_scores(data)

# Plot histogram of standardized data
plt.figure(figsize=(8,6))
plt.hist(z_scores, bins=15, edgecolor='black', alpha=0.7)
plt.title('Histogram of Z-scores')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
